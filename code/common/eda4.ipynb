# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
df = pd.read_csv(r"C:\Users\ASUS\Desktop\major_project\code\data\ABNB.csv")

# %%
df.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2020-12-10 00:00:00-05:00  146.000000  165.000000  141.250000  144.710007
# 1  2020-12-11 00:00:00-05:00  146.550003  151.500000  135.100006  139.250000
# 2  2020-12-14 00:00:00-05:00  135.000000  135.300003  125.160004  130.000000
# 3  2020-12-15 00:00:00-05:00  126.690002  127.599998  121.500000  124.800003
# 4  2020-12-16 00:00:00-05:00  125.830002  142.000000  124.910004  137.990005
#
#      Volume  Dividends  Stock Splits
# 0  70447500        0.0           0.0
# 1  26980800        0.0           0.0
# 2  16966100        0.0           0.0
# 3  10914400        0.0           0.0
# 4  20409600        0.0           0.0

# %%
df
# Out:
#                           Date        Open        High         Low  \
# 0    2020-12-10 00:00:00-05:00  146.000000  165.000000  141.250000
# 1    2020-12-11 00:00:00-05:00  146.550003  151.500000  135.100006
# 2    2020-12-14 00:00:00-05:00  135.000000  135.300003  125.160004
# 3    2020-12-15 00:00:00-05:00  126.690002  127.599998  121.500000
# 4    2020-12-16 00:00:00-05:00  125.830002  142.000000  124.910004
# ..                         ...         ...         ...         ...
# 694  2023-09-15 00:00:00-04:00  143.585007  144.949997  142.100006
# 695  2023-09-18 00:00:00-04:00  141.929993  144.399994  141.190002
# 696  2023-09-19 00:00:00-04:00  141.860001  142.570007  139.770004
# 697  2023-09-20 00:00:00-04:00  142.759995  143.270004  137.949997
# 698  2023-09-21 00:00:00-04:00  135.554993  135.979996  132.679993
#
#           Close    Volume  Dividends  Stock Splits
# 0    144.710007  70447500        0.0           0.0
# 1    139.250000  26980800        0.0           0.0
# ...

# %%
def plot_candle_stick(stock):

    fig = go.Figure(data=[go.Candlestick(x=stock['Date'],
                    open=stock['Open'],
                    high=stock['High'],
                    low=stock['Low'],
                    close=stock['Close'])])

    return fig

# %%
plot_candle_stick(df)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# %%
df = pd.read_csv(r"C:\Users\ASUS\Desktop\major_project\code\data\ACGL.csv")

# %%
df.head()
# Out:
#                         Date      Open      High       Low     Close  \
# 0  1995-09-14 00:00:00-04:00  2.277778  2.388889  2.277778  2.361111
# 1  1995-09-15 00:00:00-04:00  2.333333  2.388889  2.305556  2.361111
# 2  1995-09-18 00:00:00-04:00  2.333333  2.416667  2.333333  2.361111
# 3  1995-09-19 00:00:00-04:00  2.333333  2.416667  2.333333  2.333333
# 4  1995-09-20 00:00:00-04:00  2.333333  2.416667  2.333333  2.361111
#
#      Volume  Dividends  Stock Splits
# 0  12915900        0.0           0.0
# 1   3802500        0.0           0.0
# 2   1345500        0.0           0.0
# 3   1305000        0.0           0.0
# 4    648900        0.0           0.0

# %%
df
# Out:
#                            Date       Open       High        Low      Close  \
# 0     1995-09-14 00:00:00-04:00   2.277778   2.388889   2.277778   2.361111
# 1     1995-09-15 00:00:00-04:00   2.333333   2.388889   2.305556   2.361111
# 2     1995-09-18 00:00:00-04:00   2.333333   2.416667   2.333333   2.361111
# 3     1995-09-19 00:00:00-04:00   2.333333   2.416667   2.333333   2.333333
# 4     1995-09-20 00:00:00-04:00   2.333333   2.416667   2.333333   2.361111
# ...                         ...        ...        ...        ...        ...
# 7049  2023-09-15 00:00:00-04:00  79.019997  79.370003  78.599998  79.000000
# 7050  2023-09-18 00:00:00-04:00  79.190002  80.839996  79.070000  80.570000
# 7051  2023-09-19 00:00:00-04:00  80.650002  81.360001  80.269997  81.199997
# 7052  2023-09-20 00:00:00-04:00  81.580002  82.180000  81.000000  81.320000
# 7053  2023-09-21 00:00:00-04:00  81.000000  81.489998  80.290001  80.959999
#
#         Volume  Dividends  Stock Splits
# 0     12915900        0.0           0.0
# 1      3802500        0.0           0.0
# 2      1345500        0.0           0.0
# 3      1305000        0.0           0.0
# 4       648900        0.0           0.0
# ...        ...        ...           ...
# 7049   1964000        0.0           0.0
# 7050   1214000        0.0           0.0
# 7051   1572400        0.0           0.0
# 7052   2107300        0.0           0.0
# 7053    506073        0.0           0.0
#
# [7054 rows x 8 columns]

# %%
def plot_candle_stick(stock):

    fig = go.Figure(data=[go.Candlestick(x=stock['Date'],
                    open=stock['Open'],
                    high=stock['High'],
                    low=stock['Low'],
                    close=stock['Close'])])

    return fig

# %%
plot_candle_stick(df)

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r'C:\Users\ASUS\Desktop\pyds\Canada.xlsx')
df
# Out:
#                                            Unnamed: 0  Unnamed: 1  \
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                                 NaN         NaN
# 3                                      United Nations         NaN
# 4                                 Population Division         NaN
# 5           Department of Economic and Social Affairs         NaN
# 6                                                 NaN         NaN
# 7   International Migration Flows to and from Sele...         NaN
# 8                                                 NaN         NaN
# 9                            POP/DB/MIG/Flow/Rev.2015         NaN
# 10  December 2015 - Copyright © 2015 by United Nat...         NaN
# 11  Suggested citation: United Nations, Department...         NaN
# 12   International Migration Flows to and from Sel...         NaN
# ...

# %%
df.head()
# Out:
#             Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                  NaN        NaN        NaN        NaN        NaN        NaN
# 1                  NaN        NaN        NaN        NaN        NaN        NaN
# 2                  NaN        NaN        NaN        NaN        NaN        NaN
# 3       United Nations        NaN        NaN        NaN        NaN        NaN
# 4  Population Division        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 28 Unnamed: 29  \
# 0        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 1        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 2        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 3        NaN        NaN        NaN        NaN  ...         NaN         NaN
# 4        NaN        NaN        NaN        NaN  ...         NaN         NaN
#
# ...

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37']

# %%
df['Unnamed: 15']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19     1991
# 20        3
# 21     6535
# 22      328
# 23     4745
# 24      834
# 25     1786
# 26    14228
# 27       ..
# 28    17364
# 29    21294
# 30    32853
# 31    18453
# 32    89964
# 33    19753
# 34    24572
# 35     7804
# 36     5809
# 37    57938
# 38    12887
# 39    13474
# 40    10466
# 41    36827
# 42     6054
# 43      867
# 44     1621
# 45       ..
# 46        7
# 47     2495
# 48    25293
# Name: Unnamed: 15, dtype: object

# %%
df.iloc[[0,5,6,7,8]]   #for columns
# Out:
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                NaN        NaN        NaN
# 5          Department of Economic and Social Affairs        NaN        NaN
# 6                                                NaN        NaN        NaN
# 7  International Migration Flows to and from Sele...        NaN        NaN
# 8                                                NaN        NaN        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 5        NaN        NaN        NaN        NaN        NaN        NaN
# 6        NaN        NaN        NaN        NaN        NaN        NaN
# 7        NaN        NaN        NaN        NaN        NaN        NaN
# 8        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9  ... Unnamed: 28 Unnamed: 29 Unnamed: 30 Unnamed: 31 Unnamed: 32  \
# ...

# %%
df.iloc[:,[0,2,4,6,8]]  #for all kind of rows and counted columns
# Out:
#                                            Unnamed: 0  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                      United Nations
# 4                                 Population Division
# 5           Department of Economic and Social Affairs
# 6                                                 NaN
# 7   International Migration Flows to and from Sele...
# 8                                                 NaN
# 9                            POP/DB/MIG/Flow/Rev.2015
# 10  December 2015 - Copyright © 2015 by United Nat...
# 11  Suggested citation: United Nations, Department...
# 12   International Migration Flows to and from Sel...
# 13                                                NaN
# 14                                                NaN
# 15                          Reporting country: Canada
# ...

# %%
df.describe(exclude=np.number)  #exclude number values/columns
# Out:
#         Unnamed: 0  Unnamed: 1 Unnamed: 2        Unnamed: 3 Unnamed: 4  \
# count           41          30         31                25         30
# unique          13           3         14                24         29
# top     Immigrants  Foreigners     Africa  Northern America         ..
# freq            29          28          5                 2          2
#
#        Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  \
# count          30         30         30         30         30  ...
# unique         28         28         29         28         28  ...
# top            ..         ..         ..         ..         ..  ...
# freq            3          3          2          3          3  ...
#
#        Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29 Unnamed: 30  \
# count           30          30          30          30          30
# unique          30          30          30          30          29
# top           2002        2003        2004        2005           1
# ...
